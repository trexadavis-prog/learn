# %% [markdown]
# # Module 1 Lab: Python Basics & Variables (Self-Checking Lab)
#
# Welcome to your first lab! Here, you will write your own code to practice what you learned in the Concept Guide.
#
# ### How to use this lab:
# 1. Read the instructions for an exercise.
# 2. Write your code in the cell marked **"Write your code here"**.
# 3. Run that code cell to load your variables into the computer's memory.
# 4. Run the **Test Cell** directly below it. It will check your variables and print a message telling you if your code is correct, or give you a helpful hint if it's not!

# %% [markdown]
# ### Exercise 1: Labeled Boxes (Variables)
#
# Let's practice creating variables:
# 1. Create a variable named `student_name` and store the text `"Alex"` inside it.
# 2. Create a variable named `hours_studied` and store the number `4` inside it.

# %%
# === EXERCISE 1 ===
# Write your code below:

# %%
# === TEST CELL (Run this to check your work!) ===
try:
    if 'student_name' not in globals():
        print(" Try again: You haven't created the variable 'student_name' yet.")
    elif 'hours_studied' not in globals():
        print(" Try again: You haven't created the variable 'hours_studied' yet.")
    else:
        assert student_name == "Alex", "student_name should be 'Alex'. Check your spelling and quotes!"
        assert hours_studied == 4, "hours_studied should be the number 4 (without quotes!)"
        print(" Exercise 1 Passed! Fantastic start!")
except AssertionError as e:
    print(f" Try again: {e}")
except Exception as e:
    print(f" Error running the test: {e}")

# %% [markdown]
# ### Exercise 2: Basic Calculations
#
# Let's do some math with variables:
# 1. Create a variable `base_salary` and assign it the number `1200`.
# 2. Create a variable `bonus` and assign it the number `350`.
# 3. Create a variable `total_pay` and assign it the result of adding `base_salary` and `bonus`.

# %%
# === EXERCISE 2 ===
# Write your code below:

# %%
# === TEST CELL ===
try:
    if 'base_salary' not in globals():
        print(" Try again: 'base_salary' variable is missing.")
    elif 'bonus' not in globals():
        print(" Try again: 'bonus' variable is missing.")
    elif 'total_pay' not in globals():
        print(" Try again: 'total_pay' variable is missing.")
    else:
        assert base_salary == 1200, "base_salary should be 1200."
        assert bonus == 350, "bonus should be 350."
        assert total_pay == 1550, f"total_pay is incorrect. You got {total_pay}, but it should be 1550. Did you add base_salary and bonus?"
        print(" Exercise 2 Passed! Excellent math skills!")
except AssertionError as e:
    print(f" Try again: {e}")

# %% [markdown]
# ### Exercise 3: String Formatting (F-Strings)
#
# Let's practice injecting variables into sentences:
# 1. Create a variable `city` and store the text `"Paris"` inside it.
# 2. Create a variable `country` and store the text `"France"` inside it.
# 3. Create a variable `travel_message` and store an **F-string** inside it that says:
#  `"I want to visit Paris, France."` (Use your variables `{city}` and `{country}` to build this text).

# %%
# === EXERCISE 3 ===
# Write your code below:

# %%
# === TEST CELL ===
try:
    if 'city' not in globals():
        print(" Try again: 'city' variable is missing.")
    elif 'country' not in globals():
        print(" Try again: 'country' variable is missing.")
    elif 'travel_message' not in globals():
        print(" Try again: 'travel_message' variable is missing.")
    else:
        assert city == "Paris", "city should be 'Paris'."
        assert country == "France", "country should be 'France'."
        expected = "I want to visit Paris, France."
        assert travel_message == expected, f"travel_message should be: '{expected}'. You got: '{travel_message}'. Make sure you matched spelling, spacing, and punctuation exactly!"
        print(" Exercise 3 Passed! You've mastered F-strings!")
except AssertionError as e:
    print(f" Try again: {e}")

# %% [markdown]
# ### Exercise 4: Sharing Slices (Division & Modulo)
#
# Let's practice using remainder calculations:
# 1. Create a variable `total_slices` and assign it the number `15`.
# 2. We want to share these slices evenly among `4` friends.
# 3. Create a variable `slices_per_person` and assign it the number of **whole** slices each person gets using floor division (`//`).
# 4. Create a variable `leftover_slices` and assign it the number of remaining slices using the modulo operator (`%`).

# %%
# === EXERCISE 4 ===
# Write your code below:

# %%
# === TEST CELL ===
try:
    if 'total_slices' not in globals():
        print(" Try again: 'total_slices' is missing.")
    elif 'slices_per_person' not in globals():
        print(" Try again: 'slices_per_person' is missing.")
    elif 'leftover_slices' not in globals():
        print(" Try again: 'leftover_slices' is missing.")
    else:
        assert total_slices == 15, "total_slices should be 15."
        assert slices_per_person == 3, f"slices_per_person should be 3 (15 shared by 4 is 3 whole slices each). You got {slices_per_person}. did you use // ?"
        assert leftover_slices == 3, f"leftover_slices should be 3 (remainder of 15 / 4). You got {leftover_slices}. Did you use % ?"
        print(" Exercise 4 Passed! You've successfully split the pizza! ")
        print("\nCONGRATULATIONS! You have completed all the exercises in Lab 1!")
except AssertionError as e:
    print(f" Try again: {e}")
