# %% [markdown]
# # Module 4 Lab: Functions & Reusable Code (Self-Checking Lab)
#
# Welcome to the Functions Lab! Here, you will write your own custom functions with parameters, default values, and logic.
#
# Remember:
# 1. Write your solution in the **"Write your code here"** cell.
# 2. Run your code cell.
# 3. Run the **Test Cell** below it to verify your answer!

# %% [markdown]
# ### Exercise 1: Temperature Converter Function
#
# Let's package a temperature converter into a function:
# 1. Write a function named `to_celsius` that takes one parameter named `fahrenheit`.
# 2. Inside the function, calculate the Celsius equivalent using: `(fahrenheit - 32) * 5 / 9`.
# 3. Return the calculated Celsius value.

# %%
# === EXERCISE 1 ===
# Write your code below:

# %%
# === TEST CELL ===
try:
    if 'to_celsius' not in globals():
        print(" Try again: Function 'to_celsius' is missing.")
    else:
 # Check some conversions
        assert to_celsius(32) == 0.0, f"to_celsius(32) should return 0.0, but got {to_celsius(32)}."
        assert abs(to_celsius(212) - 100.0) < 0.001, f"to_celsius(212) should return 100.0, but got {to_celsius(212)}."
        print(" Exercise 1 Passed! Your temperature converter works perfectly!")
except AssertionError as e:
    print(f" Try again: {e}")

# %% [markdown]
# ### Exercise 2: Power Calculator with Defaults
#
# Let's practice using default parameter values:
# 1. Write a function named `power` that takes two parameters: `base` and `exponent`.
# 2. Set the default value of `exponent` to `2`.
# 3. Inside the function, calculate `base` raised to the power of `exponent` (using `base ** exponent`).
# 4. Return the result.

# %%
# === EXERCISE 2 ===
# Write your code below:

# %%
# === TEST CELL ===
try:
    if 'power' not in globals():
        print(" Try again: Function 'power' is missing.")
    else:
 # Test with both arguments provided
        assert power(2, 3) == 8, f"power(2, 3) should return 8. Got {power(2, 3)}."
 # Test with default exponent
        assert power(5) == 25, f"power(5) should use default exponent 2 and return 25. Got {power(5)}."
        print(" Exercise 2 Passed! Excellent use of default values!")
except AssertionError as e:
    print(f" Try again: {e}")

# %% [markdown]
# ### Exercise 3: Roller Coaster Entry Check
#
# Let's write a function that performs logic checks:
# 1. Write a function named `can_ride` that takes two parameters: `height` (in inches) and `age` (in years).
# 2. If `height` is `48` or more, **AND** `age` is `8` or more, return `True`.
# 3. Otherwise, return `False`.

# %%
# === EXERCISE 3 ===
# Write your code below:

# %%
# === TEST CELL ===
try:
    if 'can_ride' not in globals():
        print(" Try again: Function 'can_ride' is missing.")
    else:
        assert can_ride(50, 10) == True, "Height 50 and Age 10 should be allowed to ride (True)."
        assert can_ride(45, 9) == False, "Height 45 (too short) should not be allowed to ride (False)."
        assert can_ride(52, 7) == False, "Age 7 (too young) should not be allowed to ride (False)."
        print(" Exercise 3 Passed! Ride check function is correct!")
        print("\nCONGRATULATIONS! You have completed all the exercises in Lab 4!")
except AssertionError as e:
    print(f" Try again: {e}")
