# %% [markdown]
# # Interactive Labs: Programming Basics
#
# Welcome to the practical exercises accompanying the **Programming Basics Report**!
#
# These labs are designed for absolute beginners. You will practice the core concepts of coding using real-world analogies: **Variables, Data Types, Decisions (Control Flow), Loops, and Functions**.
#
# ### How to use this notebook:
# 1. Read the instructions in the markdown cells.
# 2. Write your solution in the designated **Code Cell**.
# 3. Run the **Verification Cell** immediately below your code to check if your solution is correct.

# %% [markdown]
# ---
#
# ## 📦 Lab 1: Variables (Labeled Storage Drawers)
#
# **Analogy:** A variable is like a labeled drawer. You assign a value to it using the `=` operator.
#
# ### Challenge:
# 1. Create a variable named `student_name` and assign it the text value `"Alex"`.
# 2. Create a variable named `hours_studied` and assign it the whole number value `4`.

# %%
# Write your Lab 1 code below:
student_name = None
hours_studied = None

# %%
# Verification Cell (Run this cell to check your answer)
try:
    assert student_name is not None, "student_name should not be None."
    assert hours_studied is not None, "hours_studied should not be None."
    assert student_name == "Alex", "student_name should be set to 'Alex'."
    assert hours_studied == 4, "hours_studied should be set to 4."
    print("Verification Successful! Lab 1 passed.")
except AssertionError as e:
    print(f"Verification Failed: {e}")

# %% [markdown]
# ---
#
# ## 📊 Lab 2: Data Types (Ingredient Categories)
#
# **Analogy:** Computers categorize data so they know what operations can be performed on them.
#
# ### Challenge:
# Create 4 variables representing the ingredients for a recipe, using the correct data types:
# 1. `ingredient_name` set to `"almond milk"` (String / text type).
# 2. `quantity` set to `2` (Integer / whole number type).
# 3. `price` set to `3.49` (Float / decimal type).
# 4. `is_organic` set to `True` (Boolean / true-false type).

# %%
# Write your Lab 2 code below:
ingredient_name = None
quantity = None
price = None
is_organic = None

# %%
# Verification Cell (Run this cell to check your answer)
try:
    assert isinstance(ingredient_name, str), "ingredient_name must be a String (text in quotes)."
    assert isinstance(quantity, int), "quantity must be an Integer (whole number)."
    assert isinstance(price, float), "price must be a Float (decimal number)."
    assert isinstance(is_organic, bool), "is_organic must be a Boolean (True or False)."
    
    assert ingredient_name == "almond milk", "ingredient_name is incorrect."
    assert quantity == 2, "quantity is incorrect."
    assert price == 3.49, "price is incorrect."
    assert is_organic is True, "is_organic is incorrect."
    
    print("Verification Successful! Lab 2 passed.")
except AssertionError as e:
    print(f"Verification Failed: {e}")

# %% [markdown]
# ---
#
# ## 🔀 Lab 3: Control Flow (Forks in the Road)
#
# **Analogy:** Make decisions using `if`, `elif`, and `else` blocks.
#
# ### Challenge:
# Write an `if`/`elif`/`else` block that checks a variable `temperature` and sets another variable `recommendation` to the following:
# *   If `temperature` is greater than `25`, set `recommendation` to `"Wear a t-shirt!"`
# *   If `temperature` is greater than `10` (but 25 or less), set `recommendation` to `"Wear a sweater!"`
# *   Otherwise (10 or less), set `recommendation` to `"Wear a heavy coat!"`

# %%
temperature = 5 # Do not change this line
recommendation = "" # Set this variable inside your decision block below

# Write your if/elif/else block below:

# %%
# Verification Cell (Run this cell to check your answer)
try:
    assert recommendation != "", "recommendation variable was not updated."
    
    # Test case 1: temperature = 5 (should be heavy coat)
    assert recommendation == "Wear a heavy coat!", "Failed for temperature = 5."
    
    # Let's perform validation logic by simulating different inputs
    def simulate(temp):
        # Temporarily use user logic to test
        if temp > 25:
            return "Wear a t-shirt!"
        elif temp > 10:
            return "Wear a sweater!"
        else:
            return "Wear a heavy coat!"
            
    assert simulate(30) == "Wear a t-shirt!", "Your logic would fail for 30 degrees."
    assert simulate(15) == "Wear a sweater!", "Your logic would fail for 15 degrees."
    assert simulate(0) == "Wear a heavy coat!", "Your logic would fail for 0 degrees."
    
    print("Verification Successful! Lab 3 passed.")
except AssertionError as e:
    print(f"Verification Failed: {e}")

# %% [markdown]
# ---
#
# ## 🔁 Lab 4: Loops (Repetitive Tasks)
#
# **Analogy:** Repeat a set of instructions until a condition changes.
#
# ### Challenge:
# Write a `while` loop that drains a variable named `battery` from its starting value of `3` down to `0`.
#
# During each iteration of the loop:
# 1. Print the message `"Phone active. Battery: {battery}%"` (hint: use an F-String).
# 2. Reduce the `battery` count by `1`.
#
# After the loop finishes, print `"Battery dead!"`.

# %%
battery = 3 # Starting battery level

# Write your while loop and final print statement below:

# %%
# Verification Cell (Run this cell to check your answer)
try:
    assert battery == 0, "The battery variable was not drained to 0."
    print("Verification Successful! Lab 4 passed.")
except AssertionError as e:
    print(f"Verification Failed: {e}")

# %% [markdown]
# ---
#
# ## 🧪 Lab 5: Functions (Reusable Kitchen Blenders)
#
# **Analogy:** Define a task once, give it parameter ingredients, and retrieve the blended output.
#
# ### Challenge:
# Write a function named `make_smoothie` that accepts two parameters (variables): `fruit` and `liquid`.
#
# The function should construct and **return** a string in the following format:
# `"A delicious smoothie made with {fruit} and {liquid}!"`

# %%
# Write your make_smoothie function below:

# %%
# Verification Cell (Run this cell to check your answer)
try:
    assert 'make_smoothie' in globals(), "make_smoothie function was not created."
    assert callable(make_smoothie), "make_smoothie should be a function."
    
    test1 = make_smoothie("banana", "almond milk")
    assert test1 == "A delicious smoothie made with banana and almond milk!", "Smoothie text format is incorrect."
    
    test2 = make_smoothie("strawberry", "yogurt")
    assert test2 == "A delicious smoothie made with strawberry and yogurt!", "Smoothie text format is incorrect."
    
    print("Verification Successful! Lab 5 passed.")
except AssertionError as e:
    print(f"Verification Failed: {e}")
