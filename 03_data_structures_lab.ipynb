# %% [markdown]
# # Module 3 Lab: Data Structures (Self-Checking Lab)
#
# Welcome to the Data Structures Lab! Here you will practice manipulating Lists, Dictionaries, and Sets.
#
# Remember:
# 1. Write your solution in the **"Write your code here"** cell.
# 2. Run your code cell.
# 3. Run the **Test Cell** below it to verify your answer!

# %% [markdown]
# ### Exercise 1: Shopping List Manager (Lists)
#
# Complete the following tasks:
# 1. Create a list called `shopping_list` with three strings: `"apples"`, `"milk"`, and `"bread"`.
# 2. Add `"eggs"` to the end of the list.
# 3. Remove `"milk"` from the list.
# 4. Find the number of items in the list and store it in a variable called `list_length`.

# %%
# === EXERCISE 1 ===
# Write your code below:

# %%
# === TEST CELL ===
try:
    if 'shopping_list' not in globals():
        print(" Try again: 'shopping_list' variable is missing.")
    elif 'list_length' not in globals():
        print(" Try again: 'list_length' variable is missing.")
    else:
        assert "milk" not in shopping_list, "Make sure you removed 'milk' from the list."
        assert "eggs" in shopping_list, "Make sure you added 'eggs' to the list."
        assert shopping_list[-1] == "eggs", "'eggs' should be at the end of the list."
        assert list_length == len(shopping_list), "list_length should be the count of elements in the final shopping_list."
        assert list_length == 3, f"Expected 3 items in the list, but got {list_length}. Items: {shopping_list}"
        print(" Exercise 1 Passed! List manipulated successfully!")
except AssertionError as e:
    print(f" Try again: {e}")

# %% [markdown]
# ### Exercise 2: Fruits Inventory (Dictionaries)
#
# Let's practice storing key-value pairs:
# 1. Create a dictionary named `inventory` containing:
#  - Key `"apples"` with value `10`
#  - Key `"oranges"` with value `5`
# 2. Add a new item to `inventory` with key `"bananas"` and value `15`.
# 3. Update the value of `"apples"` to `12`.
# 4. Retrieve the value of `"bananas"` from the dictionary and store it in a variable called `bananas_qty`.

# %%
# === EXERCISE 2 ===
# Write your code below:

# %%
# === TEST CELL ===
try:
    if 'inventory' not in globals():
        print(" Try again: 'inventory' dictionary is missing.")
    elif 'bananas_qty' not in globals():
        print(" Try again: 'bananas_qty' variable is missing.")
    else:
        assert inventory.get("apples") == 12, "Make sure apples value is updated to 12."
        assert inventory.get("oranges") == 5, "Oranges value should be 5."
        assert inventory.get("bananas") == 15, "Make sure bananas value is added as 15."
        assert bananas_qty == 15, f"Expected bananas_qty to be 15, but got {bananas_qty}. Did you retrieve it using inventory['bananas']?"
        print(" Exercise 2 Passed! You are great with dictionaries!")
except AssertionError as e:
    print(f" Try again: {e}")

# %% [markdown]
# ### Exercise 3: Common Colors (Sets)
#
# Let's find common items between lists using sets:
# - Alice likes colors: `["blue", "green", "red", "green"]`
# - Bob likes colors: `["green", "yellow", "blue"]`
#
# Write code that:
# 1. Converts Alice's colors to a set called `alice_set`.
# 2. Converts Bob's colors to a set called `bob_set`.
# 3. Finds the common colors they both like using the set **intersection** operator and stores the result in a variable called `shared_colors`.

# %%
# === EXERCISE 3 ===
# Write your code below:

# %%
# === TEST CELL ===
try:
    if 'alice_set' not in globals():
        print(" Try again: 'alice_set' is missing.")
    elif 'bob_set' not in globals():
        print(" Try again: 'bob_set' is missing.")
    elif 'shared_colors' not in globals():
        print(" Try again: 'shared_colors' is missing.")
    else:
        assert alice_set == {"blue", "green", "red"}, "Make sure alice_set is created from Alice's colors (duplicates are auto-removed)."
        assert bob_set == {"green", "yellow", "blue"}, "Make sure bob_set is created from Bob's colors."
        assert shared_colors == {"blue", "green"}, f"Expected shared_colors to be {{'blue', 'green'}}, but got {shared_colors}. Did you use .intersection()?"
        print(" Exercise 3 Passed! Set intersection computed successfully!")
        print("\nCONGRATULATIONS! You have completed all the exercises in Lab 3!")
except AssertionError as e:
    print(f" Try again: {e}")
